# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
from matplotlib import font_manager, rc
font_name = font_manager.FontProperties(fname="c:/Windows/Fonts/malgun.ttf").get_name()
rc('font', family=font_name)

# %%
df = pd.read_csv('C:/Users/User/Downloads/a.csv')

# %%
df.sort_values('지역별(3)',inplace = True)

# %%
a = pd.DataFrame(df.iloc[:,2])
b = pd.DataFrame(df.iloc[:,43])
c = pd.DataFrame(df.iloc[:,44])

# %%
d = pd.concat([a,b],axis=1)
df1 = pd.concat([d,c],axis=1)

# %%
df1 = df1.drop([0,1,2,3,4, 30,31,32,33])

# %%
df1.reset_index(inplace=True)

# %%
df1 = df1.iloc[:,1:]

# %%
x1 = df1.iloc[:,0].astype(str)
x2 = df1.iloc[:,1].astype(float)
x3 = df1.iloc[:,2].astype(float)

# %%
fig = plt.figure(figsize= (16,8))


plt.subplot(3,1,1)
plt.bar(x1,x2)

plt.subplot(3,1,2)
plt.bar(x1,x3)


plt.show()
